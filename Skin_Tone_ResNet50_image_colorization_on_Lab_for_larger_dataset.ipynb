# %% [markdown]
# <a href="https://colab.research.google.com/github/NAHIN-JZS/image_colorization/blob/main/Skin_Tone_ResNet50_image_colorization_on_Lab_for_larger_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install -q tensorflow-io
# Out:
#      |████████████████████████████████| 25.0 MB 1.4 MB/s

# %%
from numpy import zeros
from numpy import ones
from numpy.random import randint
from tensorflow.keras.optimizers import Adam
from keras.initializers import RandomNormal
from keras.models import Model
from tensorflow.keras.layers import Input
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Activation
from keras.layers import Concatenate
from keras.layers import Dropout
from keras.layers import BatchNormalization
from matplotlib import pyplot as plt
from tensorflow.keras.utils import plot_model
from skimage.color import rgb2lab, lab2rgb, rgb2gray, xyz2lab
import csv

import tensorflow_io as tfio
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.applications import ResNet50

# %%
def define_discriminator(input_image_shape,output_image_shape):
    
	# weight initialization
	init = RandomNormal(stddev=0.02) #As described in the original paper
    
	# source image input
	in_src_image = Input(shape=input_image_shape)  #Image we want to convert to another image
	# target image input
	in_target_image = Input(shape=output_image_shape)  #Image we want to generate after training. 
    
	# concatenate images, channel-wise
	merged = Concatenate()([in_src_image, in_target_image])
    
	# C64: 4x4 kernel Stride 2x2
	d = Conv2D(64, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(merged)
	d = LeakyReLU(alpha=0.2)(d)
	# C128: 4x4 kernel Stride 2x2
	d = Conv2D(128, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# C256: 4x4 kernel Stride 2x2
	d = Conv2D(256, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# second last output layer : 4x4 kernel but Stride 1x1
	d = Conv2D(512, (4,4), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# patch output
	d = Conv2D(1, (4,4), padding='same', kernel_initializer=init)(d)
	patch_out = Activation('sigmoid')(d)
	# define model
	model = Model([in_src_image, in_target_image], patch_out)
    
	opt = Adam(lr=0.0002, beta_1=0.5)
	model.compile(loss='binary_crossentropy', optimizer=opt, loss_weights=[0.5])
	return model

# %%
def define_encoder_block(layer_in, n_filters, batchnorm=True):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# add downsampling layer
	g = Conv2D(n_filters, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(layer_in)
	# conditionally add batch normalization
	if batchnorm:
		g = BatchNormalization()(g, training=True)
	# leaky relu activation
	g = LeakyReLU(alpha=0.2)(g)
	return g

# %%
# define a decoder block to be used in generator
def decoder_block(layer_in, skip_in, n_filters, dropout=True):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# add upsampling layer
	g = Conv2DTranspose(n_filters, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(layer_in)
	# add batch normalization
	g = BatchNormalization()(g, training=True)
	# conditionally add dropout
	if dropout:
		g = Dropout(0.5)(g, training=True)
	# merge with skip connection
	g = Concatenate()([g, skip_in])
	# relu activation
	g = Activation('relu')(g)
	return g

# %%
def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

# %%
def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate(axis = -1)([x, skip_features])
    x = conv_block(x, num_filters)
    return x

# %%
def define_generator(input_image_shape=(512,512,3),output_image_shape=(512,512,3)):
  """ Input """
  inputs = Input(input_image_shape)

  """ Pre-trained ResNet50 Model """
  # resnet50 = ResNet50(include_top=False, weights="imagenet", input_tensor=inputs)
  pre_model = ResNet50(include_top=False, weights="imagenet", input_tensor=inputs)
  # pre_model = tf.keras.applications.MobileNetV2(input_shape = input_image_shape, include_top=False, weights="imagenet")

  """ Encoder """
  # s1 = resnet50.get_layer("input_39").output           ## (512 x 512)
  s2 = pre_model.get_layer("conv1_relu").output        ## (256 x 256)
  s3 = pre_model.get_layer("conv2_block3_out").output  ## (128 x 128)
  s4 = pre_model.get_layer("conv3_block4_out").output  ## (64 x 64)

  '''layer_names = [
    'block_1_expand_relu',   # 64x64
    'block_3_expand_relu',   # 32x32
    'block_6_expand_relu',   # 16x16
    'block_13_expand_relu',  # 8x8
    'block_16_project',      # 4x4
]'''

  # s1 = mobileNet.get_layer('block_1_expand_relu').output
  # s2 = mobileNet.get_layer('block_3_expand_relu').output
  # s3 = mobileNet.get_layer('block_6_expand_relu').output
  # s4 = mobileNet.get_layer('block_13_expand_relu').output
  # s5 = mobileNet.get_layer('block_16_expand_relu').output

  """ Bridge """
  b1 = pre_model.get_layer("conv4_block6_out").output  ## (32 x 32)
  # b1 = mobileNet.get_layer('block_16_expand_relu').output

  """ Decoder """
  d1 = decoder_block(b1, s4, 512)                     ## (64 x 64)
  d2 = decoder_block(d1, s3, 256)                     ## (128 x 128)
  d3 = decoder_block(d2, s2, 128)                     ## (256 x 256)
  # d4 = decoder_block(d3, s1, 64)                      ## (512 x 512)
  # d4 = Conv2DTranspose(64, (2, 2), strides=2, padding="same")(d3)
  # d4 = Concatenate(axis = -1)([x, skip_features])
  # d4 = conv_block(d4, 64)

  """ Output """
  # g = Conv2DTranspose(output_image_shape[2], (4,4), strides=(2,2), padding='same')(d4) #Modified
  g = Conv2DTranspose(output_image_shape[2], (4,4), strides=(2,2), padding='same')(d3) 
  outputs = Activation('tanh')(g)  #Generates images in the range -1 to 1. So change inputs also to -1 to 1

  model = Model(inputs, outputs, name="ResNet50_U-Net")
  return model

# %%
# # define the standalone generator model - U-net
# def define_generator(input_image_shape=(256,256,1),output_image_shape=(256,256,3)):
# 	# weight initialization
# 	init = RandomNormal(stddev=0.02)
# 	# image input
# 	in_image = Input(shape=input_image_shape)
# 	# encoder model: C64-C128-C256-C512-C512-C512-C512-C512
# 	e1 = define_encoder_block(in_image, 64, batchnorm=False)
# 	e2 = define_encoder_block(e1, 128)
# 	e3 = define_encoder_block(e2, 256)
# 	e4 = define_encoder_block(e3, 512)
# 	e5 = define_encoder_block(e4, 512)
# 	e6 = define_encoder_block(e5, 512)
# 	e7 = define_encoder_block(e6, 512)
# 	# bottleneck, no batch norm and relu
# 	b = Conv2D(512, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(e7)
# 	b = Activation('relu')(b)
# 	# decoder model: CD512-CD512-CD512-C512-C256-C128-C64
# 	d1 = decoder_block(b, e7, 512)
# 	d2 = decoder_block(d1, e6, 512)
# 	d3 = decoder_block(d2, e5, 512)
# 	d4 = decoder_block(d3, e4, 512, dropout=False)
# 	d5 = decoder_block(d4, e3, 256, dropout=False)
# 	d6 = decoder_block(d5, e2, 128, dropout=False)
# 	d7 = decoder_block(d6, e1, 64, dropout=False)
# 	# output
# 	g = Conv2DTranspose(output_image_shape[2], (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d7) #Modified 
# 	out_image = Activation('tanh')(g)  #Generates images in the range -1 to 1. So change inputs also to -1 to 1
# 	# define model
# 	model = Model(in_image, out_image)
# 	return model

# %%
# define the combined generator and discriminator model, for updating the generator
def define_gan(g_model, d_model, input_image_shape,mask_image_shape):
	# make weights in the discriminator not trainable
	for layer in d_model.layers:
		if not isinstance(layer, BatchNormalization):
			layer.trainable = False
            
	# define the source image
	in_src = Input(shape=input_image_shape)
	mask = Input(shape= mask_image_shape)
	# suppy the image as input to the generator 
	gen_out = g_model(in_src)
	
	mask_gen_out = tf.math.multiply(gen_out,mask)
	# supply the input image and generated image as inputs to the discriminator
	dis_out = d_model([in_src, gen_out])
	# src image as input, generated image and disc. output as outputs
	model = Model([in_src,mask], [dis_out, gen_out, mask_gen_out])
	# compile model
	opt = Adam(lr=0.0002, beta_1=0.5)
    
	model.compile(loss=['binary_crossentropy', 'mae', 'mae'], 
               optimizer=opt, loss_weights=[1,50,50])
	return model

# %%
def generate_real_samples(dataset, n_samples, patch_shape):
	# unpack dataset
	trainA, trainB = dataset
	# choose random instances
	ix = randint(0, trainA.shape[0], n_samples)
	# retrieve selected images
	X1, X2 = trainA[ix], trainB[ix]
	# X1, X2 = trainA, trainB
	# generate 'real' class labels (1)
	y = ones((n_samples, patch_shape, patch_shape, 1))
	return [X1, X2], y

# %%
# generate a batch of images, returns images and targets
def generate_fake_samples(g_model, samples, patch_shape):
	#To make the source image into 3 channels so that it can be feed into the resnet50 model
	# samples = np.repeat(samples, repeats = 3, axis = -1)
	# generate fake instance
	X = g_model.predict(samples)
	# create 'fake' class labels (0)
	y = zeros((len(X), patch_shape, patch_shape, 1))
	return X, y

# %%
def summarize_performance(step, g_model, d_model, gan_model, weight_folder):
	# select a sample of input images
	
	# save the generator model
	g_model_filename = weight_folder + '/g_model_%06d.h5' % (step+1)
	g_model.save(g_model_filename)
	print('>Saved: %s' % ( g_model_filename))

	# save the discriminator model
	d_model_filename = weight_folder + '/d_model_%06d.h5' % (step+1)
	d_model.save(d_model_filename)
	print('>Saved: %s' % (d_model_filename))

	# save the gan model
	gan_model_filename = weight_folder + '/gan_model_%06d.h5' % (step+1)
	gan_model.save(gan_model_filename)
	print('>Saved: %s' % ( gan_model_filename))

# %%
import tensorflow as tf
from os import listdir
from numpy import asarray, load
from numpy import vstack
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from numpy import savez_compressed
from matplotlib import pyplot
import numpy as np
from PIL import Image, ImageOps

# %%
# This function will create a list of image path
def generate_image_path_list(folder_name):
  path_list = list() 
  for filename in listdir(folder_name):
    path_list.append(filename)
  return path_list

# %%
# load all images in a directory into memory
def load_images(im_indecator, im_path_list,mask_path_list, im_path,mask_path, batch_size, size=(256,256)):
	src_list, tar_list, mask_list = list(), list(), list()
	# enumerate filenames in directory, assume all are images
	# for filename in listdir(path):
	if ((im_indecator + batch_size) > len(im_path_list)):
		batch_size = len(im_path_list) - im_indecator
	for j in range(batch_size):

		# load and resize the image
		#pixels = load_img(path + filename, target_size=size)
		rgb_image = load_img(path + im_path_list[im_indecator+j], target_size=size)
		#gray_image = ImageOps.grayscale(rgb_image)
		# gray_image = tf.image.rgb_to_grayscale(rgb_image)
		# convert to numpy array
		rgb_pixels = img_to_array(rgb_image)
	
		#-----lab conversion--------#
		rgb_pixels = rgb_pixels/255.0
		lab = tfio.experimental.color.rgb_to_lab(rgb_pixels)
		lab_pixels = (lab)/100.0

		

		# rgb_np_array = np.array(rgb_pixels, dtype=float)
		# lab_pixels = rgb2lab(1.0/255*rgb_np_array)



		gray_pixels = lab_pixels[:,:,0]
		gray_pixels = np.expand_dims(gray_pixels, axis=2)
	
		#To make the source image into 3 channels so that it can be feed into the resnet50 model
		gray_pixels = np.repeat(gray_pixels, repeats = 3, axis = -1)

		ab_pixels = lab_pixels[:,:,1:]


		#Loading the mask image
		mask = load_img(mask_path + mask_path_list[im_indecator + j ], target_size=size)
		mask_pixels = img_to_array(mask)
		mask_pixels = np.expand_dims(mask_pixels[:,:,0],axis=2)


		# gray_pixels = img_to_array(gray_image)
		# split into satellite and map
		#sat_img, map_img = pixels[:, :256], pixels[:, 256:]
		src_list.append(gray_pixels)
		tar_list.append(ab_pixels)
		mask_list.append(mask_pixels)
	return [asarray(src_list), asarray(tar_list),asarray(mask_list),batch_size]

# %%
# def preprocess_data(data):
# 	# load compressed arrays
# 	# unpack arrays
# 	X1, X2 = data[0], data[1]
# 	# scale from [0,255] to [-1,1]
# 	X1 = (X1 - 127.5) / 127.5
# 	X2 = (X2 - 127.5) / 127.5
# 	return [X1, X2]

# %%
# train pix2pix models
# def train(d_model, g_model, gan_model, dataset, n_epochs=100, n_batch=1):

def train(d_model, g_model, gan_model, im_path_list, mask_path_list, mask_path, im_path, weight_folder, save_weight_file_after = 10, n_epochs=100, n_batch=1):
	"""This function is used to train the GAN

	Args:
		d_model (keras model): discriminator model
		g_model (keras model): generator model
		gan_model (keras model): combine of d_model and g_model or GAN
		im_path_list (list): this will contain all image name in the dataset(main image) folder
		im_path (string): dataset path or image path 
		weight_folder (string): folder to save weight file
		save_weight_file_after (int, optional): number of epoch to save weight file. mane koita wpoch er por weight file save korbe. Defaults to 10.
		n_epochs (int, optional): Total number of epoch. Defaults to 100.
		n_batch (int, optional): number of batch. Defaults to 1.
	"""


	# determine the output square shape of the discriminator
	n_patch = d_model.output_shape[1]
	# unpack dataset
	# trainA, trainB = dataset
	# calculate the number of batches per training epoch
	# bat_per_epo = int(len(trainA) / n_batch)
	# calculate the number of training iterations
	# n_steps = bat_per_epo * n_epochs
	# manually enumerate epochs
	total_image = len(im_path_list);
	# d1_loss_list = list()
	# d2_loss_list = list()
	# g_loss_list = list()

	for i in range(n_epochs):
		im_indicator = 0 # Track of current image
		
		n_last_batch = n_batch # n_last_batch will work as number of batch...but to update after one epoch this has been written

		while (im_indicator < total_image):
				# [src_images, tar_images]  = load_images(im_indicator, im_path_list = im_path_list, im_path = im_path, batch_size = n_batch)
				# dataset = preprocess_data([src_images, tar_images])
				# dataset  = load_images(im_indicator, im_path_list = im_path_list, im_path = im_path, batch_size = n_batch)
				[src_images, tar_images,mask,n_last_batch]  = load_images(im_indicator, im_path_list = im_path_list, im_path = im_path, mask_path_list= mask_path_list,mask_path= mask_path, batch_size = n_batch)
				dataset = [src_images,tar_images]
				# print(tar_images.shape)
				# print(mask.shape)
				trainA, trainB = dataset

				im_indicator = im_indicator + n_last_batch


				# select a batch of real samples
				[X_realA, X_realB], y_real = generate_real_samples(dataset, n_last_batch, n_patch)
				# generate a batch of fake samples
				X_fakeB, y_fake = generate_fake_samples(g_model, X_realA, n_patch)
		

				#masking the ground_truth
				# print(X_realB.shape)
				mask_tar_out = tf.math.multiply(X_realB,mask)
		


				# update discriminator for real samples
				d_loss1 = d_model.train_on_batch([X_realA, X_realB], y_real)
				# d1_loss_list.append(d_loss1)
				# update discriminator for generated samples
				d_loss2 = d_model.train_on_batch([X_realA, X_fakeB], y_fake)
				# d2_loss_list.append(d_loss2)
				# update the generator
				g_loss,skin_loss, _, _ = gan_model.train_on_batch([X_realA,mask], [y_real, X_realB,mask_tar_out])
				# g_loss_list.append(g_loss)
				# summarize performance
				print('>epoch: %d, batch: %d, d1[%.3f] d2[%.3f] g[%.3f] s[%.3f]' % (i+1,np.ceil(im_indicator/n_batch), d_loss1, d_loss2, g_loss, skin_loss))
				# summarize model performance
		if (i+1) %  save_weight_file_after == 0:

			# [src_images, tar_images]  = load_images(im_indicator- n_batch , im_path_list = im_path_list, im_path = im_path, batch_size = n_batch)
			# dataset = preprocess_data([src_images, tar_images])
			summarize_performance(i, g_model = g_model, d_model = d_model, gan_model = gan_model, weight_folder = weight_folder)

# %%
# """Checking the load_images function...ignore"""




# path = '/content/gdrive/MyDrive/3200_Project/Project/Zahim_folder/New_Image/'
# path_list = generate_image_path_list(path)
# # load dataset
# [src_images, tar_images] = load_images(im_indecator = 0, im_path_list = path_list, im_path = path, batch_size = 1, size=(256,256))
# print('Loaded: ', src_images.shape, tar_images.shape)


# n_samples = 1
# for i in range(n_samples):
# 	pyplot.subplot(2, n_samples, 1 + i)
# 	pyplot.axis('off')
# 	re = np.squeeze(src_images[i])
# 	pyplot.imshow(re.astype('uint8'),'gray')
# # plot target image
# for i in range(n_samples):
# 	pyplot.subplot(2, n_samples, 1 + n_samples + i)
# 	pyplot.axis('off')
# 	pyplot.imshow(tar_images[i].astype('uint8'))
# pyplot.show()

#######################################

# %%
#from pix2pix_model import define_discriminator, define_generator, define_gan, train
# define input shape based on the loaded dataset
# input_image_shape = src_images.shape[1:]
# output_image_shape = tar_images.shape[1:]
input_image_shape = (256,256,3)
output_image_shape = (256,256,2)
mask_image_shape = (256,256,1)
# define the models
d_model = define_discriminator(input_image_shape,output_image_shape)
g_model = define_generator(input_image_shape,output_image_shape)
# define the composite model
gan_model = define_gan(g_model, d_model, input_image_shape,mask_image_shape)

#Define data
# load and prepare training images
# data = [src_images, tar_images]
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
path = '/content/gdrive/MyDrive/Thesis/Dataset/skin_tone_clothing/skin_segmentation_images_original/'
weight_folder = '/content/gdrive/MyDrive/Thesis/Dataset/test/chkpoint'
path_list = generate_image_path_list(path)
path_list.sort()
print(np.array(path_list).shape)
# Out:
# (1000,)

# %%
mask_path = '/content/gdrive/MyDrive/Thesis/Dataset/skin_tone_clothing/skin_segmentation_masks_original_0_1/'
mask_path_list = generate_image_path_list(mask_path)
mask_path_list.sort()
print(np.array(mask_path_list).shape)
# Out:
# (1000,)

# %%
path_list[61],mask_path_list[61]
# Out:
# ('img_0062.png', 'seg_0062.png')

# %%
from datetime import datetime 
start1 = datetime.now() 

# train(d_model, g_model, gan_model, dataset, n_epochs=150, n_batch=1) 
train(d_model, g_model, gan_model, im_path_list = path_list, mask_path_list = mask_path_list, im_path = path,save_weight_file_after = 5, mask_path = mask_path, weight_folder = weight_folder, n_epochs=100, n_batch=32)
stop1 = datetime.now()
#Execution time of the model 
execution_time = stop1-start1
print("Execution time is: ", execution_time)
# Out:
# 1/1 [==============================] - 0s 38ms/step
# >epoch: 1, batch: 1, d1[0.002] d2[0.002] g[2.002] s[0.005]
# 1/1 [==============================] - 0s 56ms/step
# >epoch: 1, batch: 2, d1[0.003] d2[0.002] g[2.305] s[0.005]
# 1/1 [==============================] - 0s 31ms/step
# >epoch: 1, batch: 3, d1[0.002] d2[0.002] g[2.348] s[0.005]
# 1/1 [==============================] - 0s 33ms/step
# >epoch: 1, batch: 4, d1[0.002] d2[0.002] g[2.323] s[0.004]
# 1/1 [==============================] - 0s 32ms/step
# >epoch: 1, batch: 5, d1[0.002] d2[0.002] g[2.376] s[0.004]
# 1/1 [==============================] - 0s 32ms/step
# >epoch: 1, batch: 6, d1[0.002] d2[0.002] g[2.714] s[0.003]
# 1/1 [==============================] - 0s 31ms/step
# >epoch: 1, batch: 7, d1[0.002] d2[0.002] g[2.176] s[0.003]
# 1/1 [==============================] - 0s 32ms/step
# >epoch: 1, batch: 8, d1[0.002] d2[0.003] g[2.393] s[0.004]
# 1/1 [==============================] - 0s 32ms/step
# >epoch: 1, batch: 9, d1[0.001] d2[0.002] g[2.625] s[0.005]
# 1/1 [==============================] - 0s 34ms/step
# >epoch: 1, batch: 10, d1[0.002] d2[0.002] g[2.755] s[0.004]
# 1/1 [==============================] - 0s 32ms/step
# >epoch: 1, batch: 11, d1[0.002] d2[0.002] g[2.628] s[0.004]
# 1/1 [==============================] - 0s 34ms/step
# >epoch: 1, batch: 12, d1[0.002] d2[0.002] g[2.490] s[0.004]
# 1/1 [==============================] - 0s 33ms/step
# >epoch: 1, batch: 13, d1[0.002] d2[0.002] g[2.201] s[0.005]

# %%
#Test trained model on image...

from keras.models import load_model
from numpy.random import randint
model = load_model('/content/gdrive/MyDrive/Thesis/Dataset/test/chkpoint/g_model_000010.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
# load all images in a directory into memory
def load_single_images(path, size=(256,256)):
  src_list, tar_list = list(), list()
  if( path[-1:] != '/'):
    # load and resize the image
		#pixels = load_img(path + filename, target_size=size)
    rgb_image = load_img(path, target_size=size)
		#gray_image = ImageOps.grayscale(rgb_image)
		# gray_image = tf.image.rgb_to_grayscale(rgb_image)
		# convert to numpy array
    rgb_pixels = img_to_array(rgb_image)
    # rgb_np_array = np.array(rgb_pixels, dtype=float)
    # lab_pixels = rgb2lab(1.0/255*rgb_np_array)
    
    #-----lab conversion------#
    rgb_pixels = rgb_pixels/255.0
    # rgb_pixels = tf.image.convert_image_dtype(rgb_pixels, dtype=tf.float32) # to normalize the rgb pixels
    lab = tfio.experimental.color.rgb_to_lab(rgb_pixels)
    lab_pixels = (lab)/100.0

    gray_pixels = lab_pixels[:,:,0]
    gray_pixels = np.expand_dims(gray_pixels, axis=2)
    #To make the source image into 3 channels so that it can be feed into the resnet50 model
    gray_pixels = np.repeat(gray_pixels, repeats = 3, axis = -1)
    # gray_pixels = np.squeeze(gray_pixels)
    ab_pixels = lab_pixels[:,:,1:]


		# gray_pixels = img_to_array(gray_image)
		# split into satellite and map
		#sat_img, map_img = pixels[:, :256], pixels[:, 256:]
    src_list.append(gray_pixels)
    tar_list.append(ab_pixels)
    return [asarray(src_list), asarray(tar_list)]
  # enumerate filenames in directory, assume all are images
  for filename in listdir(path):
		# load and resize the image
		#pixels = load_img(path + filename, target_size=size)
    rgb_image = load_img(path + filename, target_size=size)
    # rgb_image = load_img(path, target_size=size)
		#gray_image = ImageOps.grayscale(rgb_image)
		# gray_image = tf.image.rgb_to_grayscale(rgb_image)
		# convert to numpy array
    rgb_pixels = img_to_array(rgb_image)
    rgb_np_array = np.array(rgb_pixels, dtype=float)
    # lab_pixels = rgb2lab(1.0/255*rgb_np_array)

    #-----lab conversion------#
    rgb_pixels = rgb_pixels/255.0
    # rgb_pixels = tf.image.convert_image_dtype(rgb_pixels, dtype=tf.float32) # to normalize the rgb pixels
    lab = tfio.experimental.color.rgb_to_lab(rgb_pixels)
    lab_pixels = (lab)/100.0


    gray_pixels = lab_pixels[:,:,0]
    gray_pixels = np.expand_dims(gray_pixels, axis=2)
    #To make the source image into 3 channels so that it can be feed into the resnet50 model
    gray_pixels = np.repeat(gray_pixels, repeats = 3, axis = -1)
    # gray_pixels = np.squeeze(gray_pixels)
    ab_pixels = lab_pixels[:,:,1:]


		# gray_pixels = img_to_array(gray_image)
		# split into satellite and map
		#sat_img, map_img = pixels[:, :256], pixels[:, 256:]
    src_list.append(gray_pixels)
    tar_list.append(ab_pixels)
  
  return [asarray(src_list), asarray(tar_list)]

# %%
import tensorflow_io as tfio
rgb_image = load_img('/content/gdrive/MyDrive/Thesis/Dataset/test/few_image/20057.jpg', target_size=(256,256))
#gray_image = ImageOps.grayscale(rgb_image)
# gray_image = tf.image.rgb_to_grayscale(rgb_image)
# convert to numpy array
rgb_pixels = img_to_array(rgb_image)
rgb_pixels = rgb_pixels/255.0
# rgb_pixels = tf.image.convert_image_dtype(rgb_pixels, dtype=tf.float32) # to normalize the rgb pixels
lab = tfio.experimental.color.rgb_to_lab(rgb_pixels)
lab_pixel = (lab)/100.0
# rgb_np_array = np.array(rgb_pixels, dtype=float)

src = lab_pixel[:,:,0]
src = np.expand_dims(src, axis=2)
tar = lab_pixel[:,:,1:]
print(src.shape)
lab_gen = np.concatenate([src,tar],axis = 2)

lab_gen = (lab_gen*100)
rgb = tfio.experimental.color.lab_to_rgb(lab_gen)
rgb = np.array(rgb)
# print(rgb)
print(np.array(lab_pixel).max())
pyplot.imshow(rgb,'gray')
# lab_pixels = rgb2lab(1.0/255*rgb_np_array)
# gray_pixels = lab_pixels[:,:,0]
# ab_pixels = lab_pixels[:,:,1:]
# Out:
# (256, 256, 1)
# 1.0

# %%
# test_data = load_images('/content/gdrive/MyDrive/Thesis/Dataset/test/few_image/20056.jpg')
src_image, tar_image = load_single_images('/content/gdrive/MyDrive/Thesis/Dataset/skin_tone_clothing/png_images/IMAGES/img_0001.png')
# src_image, tar_image = preprocess_data(test_data)

# %%
print(src_image.shape)

# src_image = np.squeeze(src_image)
# src_image = np.expand_dims(src_image, axis=2)
print(src_image.shape)
# Out:
# (1, 256, 256, 3)
# (1, 256, 256, 3)

# %%
# gen_image = model.predict(src_image)

# %%
src_image.shape
# Out:
# (1, 256, 256, 3)

# %%
gen_image = model.predict(src_image)
src_image = np.squeeze(src_image)
src_image = np.expand_dims(src_image, axis=2)
gen_image = np.squeeze(gen_image)
# Out:
# 1/1 [==============================] - 0s 23ms/step

# %%
# gen_image = model.predict(src_image)
src_image = np.squeeze(src_image)
src_image = np.expand_dims(src_image[:,:,0], axis=2)
gen_image = np.squeeze(gen_image)
gen_image.shape
# Out:
# (256, 256, 2)

# %%
# lab_gen = np.concatenate([src_image,gen_image],axis = 2)

# lab_gen = (lab_gen*100)
# rgb = tfio.experimental.color.lab_to_rgb(lab_gen)
# rgb = np.array(rgb)
# # print(rgb)
# print(np.array(lab_gen).max())
# pyplot.imshow(rgb,'gray')

# %%
lab_gen = np.concatenate([src_image,gen_image],axis = 2)

lab_gen = (lab_gen*100)
rgb = tfio.experimental.color.lab_to_rgb(lab_gen)
rgb = np.array(rgb)
# print(rgb)
print(np.array(lab_gen).max())
pyplot.axis('off')
pyplot.imshow(rgb,'gray')
pyplot.title('Lab OUTPUT')
pyplot.show()
# Out:
# 100.0

# %%
from math import log10, sqrt
import cv2
import numpy as np

def PSNR(original, compressed):
	mse = np.mean((original - compressed) ** 2)
	if(mse == 0): # MSE is zero means no noise is present in the signal .
				# Therefore PSNR have no importance.
		return 100
	max_pixel = 255.0
	psnr = 20 * log10(max_pixel / sqrt(mse))
	return psnr

# original = cv2.imread("D:\Thesis\data\dataU\data\\20056.jpg")
# compressed = cv2.imread("D:\Thesis\data\dataU\data\\20057.jpg", 1)
# value = PSNR(original, compressed)
value = PSNR(tar_image, gen_image)
print(f"PSNR value is {value} dB")
# Out:
# PSNR value is 48.11653955755136 dB

# %%
from math import log10, sqrt
import cv2
import numpy as np

def MAE(original, compressed):
	mae = np.mean(np.abs((original - compressed)))
	# if(mse == 0): # MSE is zero means no noise is present in the signal .
	# 			# Therefore PSNR have no importance.
	# 	return 100
	# mae =mae
	# psnr = 20 * log10(max_pixel / sqrt(mse))
	return mae

# original = cv2.imread("D:\Thesis\data\dataU\data\\20056.jpg")
# compressed = cv2.imread("D:\Thesis\data\dataU\data\\20057.jpg", 1)
# value = PSNR(original, compressed)
value = PSNR(gen_image, tar_image)
print(f"PSNR value is {value} dB")
# Out:
# PSNR value is 48.11653955755136 dB

# %%
import cv2
import numpy as np
from skimage.metrics import structural_similarity

def SSIM(original, compressed):
	(score, diff) = structural_similarity(original, compressed ,multichannel = True, full=True)
	return score

# %%
s, t = load_images('/content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_HR/0004.png')

# %%
import cv2
test_img_path = '/content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256'
save_path = 'D:\Thesis\output\RGB_PASCAL_DIV2K'+'\\'
psnr_list = []
for filename in listdir(test_img_path):
    print(test_img_path+'/'+filename)
    img = cv2.imread(test_img_path+filename)
    src_image, tar_image = load_images(test_img_path+'/'+filename)

    
    # src_image, tar_image = preprocess_data(test_data)
    # generate image from source
    gen_image = model.predict(src_image)

    pyplot.axis('off')
    
    gen_image = np.squeeze(gen_image)

    src_image = np.squeeze(src_image)
    src_image = np.expand_dims(src_image, axis=2)

    print(gen_image.shape,src_image.shape)

    lab_gen = np.concatenate([src_image,gen_image],axis = 2)

    lab_gen = (lab_gen*100)
    rgb = tfio.experimental.color.lab_to_rgb(lab_gen)
    rgb = np.array(rgb)

    tar_image = np.squeeze(tar_image)
    
    lab_tar = np.concatenate([src_image,tar_image],axis = 2)

    lab_tar = (lab_tar*100)
    rgb_tar = tfio.experimental.color.lab_to_rgb(lab_tar)
    rgb_tar = np.array(rgb_tar)


    psnr= SSIM(rgb_tar, rgb)
    # psnr = 
    print(psnr)
    psnr_list.append(psnr)
    

    # plot all three images
    # plot_images(src_image, gen_image, tar_image,save_path+filename)

    # print(img)
    # cv2.imwrite(save_path+filename,img)

plt.plot(psnr_list)
plt.show()
# Out:
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0013.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4259301783326775
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0005.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.46088558429875137
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0010.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4527976269167326
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0003.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4299328004041592
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0002.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4316456973981216
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0001.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3582810438397966
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0006.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.40452485460419263
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0007.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4051272359223938
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0009.png
# 1/1 [==============================] - 0s 29ms/step
# (256, 256, 2) (256, 256, 1)
# 0.48485731876554855
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0008.png
# 1/1 [==============================] - 0s 28ms/step
# (256, 256, 2) (256, 256, 1)
# 0.378645518447186
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0004.png
# 1/1 [==============================] - 0s 25ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5604119318253619
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0035.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.45742044270632815
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0039.png
# 1/1 [==============================] - 0s 29ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4866239023051178
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0033.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4143479173559892
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0038.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3156157115347726
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0034.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3871355366636828
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0031.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.42383039954826157
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0037.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5095706859900003
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0040.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5328407697291572
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0036.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5727078082360614
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0032.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5158267185125519
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0025.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.48006468344775305
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0021.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.49222401090477713
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0024.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.31376047185820877
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0026.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3466956920667626
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0022.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.46376350633258046
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0030.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4471846782800088
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0028.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4482960326169414
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0027.png
# 1/1 [==============================] - 0s 30ms/step
# (256, 256, 2) (256, 256, 1)
# 0.44858385642585535
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0029.png
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3966247233758779
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0023.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.46774683347674206
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0019.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.44686883955517304
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0015.png
# 1/1 [==============================] - 0s 24ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4848315787175261
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0018.png
# 1/1 [==============================] - 0s 24ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4079415046177921
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0020.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.43104798036417624
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0012.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4027120054416324
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0016.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4633655415382147
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0011.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.42147843834484405
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0014.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.49806858510186336
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0017.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4611439793040392
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0066.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4358725330698978
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0063.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3866873771481985
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0061.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.44002948584837004
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0067.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4892167531143072
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0068.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4460959583536705
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0062.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.40594025221338087
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0059.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.46451316880201193
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0060.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.527134797777527
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0058.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3671248754305472
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0056.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5396885455463948
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0057.png
# 1/1 [==============================] - 0s 24ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5844423630643214
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0054.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.359509099459689
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0052.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4456567484442626
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0055.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.37109303521356346
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0053.png
# 1/1 [==============================] - 0s 25ms/step
# (256, 256, 2) (256, 256, 1)
# 0.47676485199934
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0051.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5315777182857527
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0048.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.7227081652487376
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0045.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.49383464413016326
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0046.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.45092536438707914
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0047.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4894654813453587
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0042.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4615646707428358
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0050.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4332106749303124
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0044.png
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 2) (256, 256, 1)
# 0.44602557700591783
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0049.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4994791830360019
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0043.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.519280744176657
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0041.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.522382246230817
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0065.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.41937655664777324
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0064.png
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3625973735762303
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0069.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3949134143448798
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0070.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.48378536950272144
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0091.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5486941729713722
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0090.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.416559827951791
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0086.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5102014230965004
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0087.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.41579536140814716
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0082.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4354257842531241
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0089.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.37406853172949633
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0088.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3892378858386494
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0081.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.45807464614305005
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0083.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.446934848045061
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0085.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.43622262521129507
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0084.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5430876662998491
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0073.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4884266514518239
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0076.png
# 1/1 [==============================] - 0s 25ms/step
# (256, 256, 2) (256, 256, 1)
# 0.33019238889516744
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0071.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4511883386070595
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0075.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.38507255776056737
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0074.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4460184313027617
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0078.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4054750625889949
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0072.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.477254784887573
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0080.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.569677152031244
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0079.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4628889772801837
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0077.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.49593160474309866
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0118.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.42086898060684447
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0108.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5005286085584602
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0104.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3867776296883156
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0110.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.43843344202972195
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0105.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4492572702597688
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0106.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5377429027413395
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0102.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4054886439108374
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0107.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4121892617365017
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0109.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3061543883339561
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0103.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5661239122483624
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0101.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.34324134080702656
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0100.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.43928801675571316
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0095.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4931566498483657
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0094.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3663334868967823
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0099.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4241343820443275
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0096.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.45309790155332347
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0098.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3732785565810352
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0093.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4172783841124796
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0097.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.35964686396884044
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0092.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5420026294980019
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0135.png
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4055322833745496
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0140.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.42838529515949014
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0137.png
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4062719346598927
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0139.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4200352896745559
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0134.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.48912977070988223
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0136.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5035045637378888
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0132.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3992168157465085
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0138.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5718028480069491
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0133.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.496158377413286
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0131.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5408859430384386
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0125.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4548939416775705
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0122.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4206911376440183
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0124.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.36415396267814093
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0128.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3423586071412444
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0129.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4227872928526872
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0126.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3388765613738576
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0130.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4751484613793929
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0123.png
# 1/1 [==============================] - 0s 25ms/step
# (256, 256, 2) (256, 256, 1)
# 0.35794141772282306
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0127.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5035839547642856
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0121.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4947459209525456
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0114.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4427405849026475
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0111.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5156127215147075
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0113.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.43688381688555694
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0116.png
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4532282323749392
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0117.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4769682931001607
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0112.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3751007678895724
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0120.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4907807574824532
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0115.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3241426112661434
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0119.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5472825178704267
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0161.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.48669707948440094
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0156.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.49616322114712297
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0155.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4396844501775175
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0152.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.45421492226446897
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0154.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.526474899939212
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0159.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.514678730569452
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0160.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.37340768224157345
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0153.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4412561867153923
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0151.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4577104444161642
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0158.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.493664556887849
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0157.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4493305757242801
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0144.png
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4639182937024797
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0145.png
# 1/1 [==============================] - 0s 24ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4555351712925373
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0143.png
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 2) (256, 256, 1)
# 0.43355075156487954
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0146.png
# 1/1 [==============================] - 0s 24ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4586595902229707
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0149.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4841296655214398
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0147.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.44896792376879113
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0148.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5264874582516791
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0142.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4710950732498184
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0150.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5697802003459912
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0141.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4513361166821386
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0182.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4351624466214983
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0184.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4650541707290416
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0183.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.33120501654298323
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0190.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4486902984792152
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0188.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4896840198032608
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0186.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3528004900321025
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0189.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.49420053602865927
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0187.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3722261402127254
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0185.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.40920363261420095
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0181.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4024427458120456
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0180.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5084958467821287
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0175.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.43727228588756645
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0174.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.40611755924263376
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0173.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4255183997155509
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0179.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3991689794468795
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0172.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5138462843564486
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0177.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5870600036279527
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0178.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.43642496325951985
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0171.png
# 1/1 [==============================] - 0s 24ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5238400760230618
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0176.png
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3563970746564173
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0166.png
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 2) (256, 256, 1)
# 0.43758315735973835
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0169.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4313865869507289
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0165.png
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 2) (256, 256, 1)
# 0.49531692628693547
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0163.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4849967350855138
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0164.png
# 1/1 [==============================] - 0s 24ms/step
# (256, 256, 2) (256, 256, 1)
# 0.34349067036530806
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0162.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.43653428359141655
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0167.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5121855752978675
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0168.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.38781270870257306
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0170.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4878953286930818
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0213.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.42311323318588245
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0212.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.36758107406097756
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0214.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.42644073666880455
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0216.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.39920336211660595
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0218.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.417322926192548
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0211.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3594937119793528
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0207.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.39760684787744455
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0204.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.46512799512836334
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0210.png
# 1/1 [==============================] - 0s 24ms/step
# (256, 256, 2) (256, 256, 1)
# 0.43324982851803046
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0206.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4061606118132813
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0205.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4463694936629403
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0203.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.41872673340780536
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0208.png
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 2) (256, 256, 1)
# 0.47512081234446574
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0201.png
# 1/1 [==============================] - 0s 26ms/step
# (256, 256, 2) (256, 256, 1)
# 0.43980947321662245
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0202.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4650698839910697
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0209.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.555178117981353
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0200.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4728145246920485
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0199.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3966493469630051
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0198.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3721709213599189
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0197.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3757534149870216
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0195.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3781671998382527
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0194.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5554278822745654
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0192.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4234299416262281
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0193.png
# 1/1 [==============================] - 0s 26ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5388932824576237
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0191.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.383885807683443
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0196.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3476603857443603
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0241.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5347820059608169
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0234.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.29237241586559654
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0236.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4754987523430301
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0233.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.47833262682624644
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0237.png
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5084704076017066
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0238.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.43656855296776076
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0235.png
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 2) (256, 256, 1)
# 0.43687362007338154
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0232.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4826741370804846
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0240.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3683929629151362
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0239.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4192843879124412
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0231.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.37189537655384136
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0229.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.503708859463574
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0228.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4279424743776777
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0225.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.38048026250612715
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0222.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5215835072228076
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0230.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.44742108501158745
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0224.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4774916396789453
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0227.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5281788380092337
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0221.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.36596263363420095
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0226.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.44047906056811903
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0223.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.43704800204058847
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0215.png
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4631901247576294
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0217.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5419214918940874
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0220.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4668398760448153
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0219.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.49730429616500577
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0270.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.37794261669932877
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0264.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5205931240387826
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0267.png
# 1/1 [==============================] - 0s 24ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4973842371117823
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0261.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.472373116840538
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0269.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3973904624249511
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0263.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.39406682873138293
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0268.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.39736669998941593
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0265.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4507232246236335
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0266.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.32483039813092884
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0262.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5372257458549726
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0257.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.42188282876483174
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0260.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.46719359758398493
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0256.png
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 2) (256, 256, 1)
# 0.27468691390965944
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0253.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4806226316587365
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0258.png
# 1/1 [==============================] - 0s 25ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3638725951363773
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0252.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.44290718690097136
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0251.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.35235846022010947
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0259.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.48466214475971237
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0255.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5102459593566612
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0254.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5036173188613202
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0247.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4661450009195915
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0246.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4950207876599122
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0250.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.39225455383586144
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0243.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3856759051737429
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0249.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.43931198993608317
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0244.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4935167006839672
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0248.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.40297268448465856
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0242.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.48904847327681145
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0245.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3757607735336734
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0298.png
# 1/1 [==============================] - 0s 25ms/step
# (256, 256, 2) (256, 256, 1)
# 0.39069589385235065
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0294.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3847196044615974
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0293.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5068685235648279
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0296.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4063862675893802
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0281.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3777608667329024
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0287.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4949283256282217
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0284.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3747079642703057
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0286.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.45203518689377914
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0289.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5243146130193975
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0283.png
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 2) (256, 256, 1)
# 0.43088392407886267
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0288.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.38072886573802717
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0290.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3980173959565599
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0285.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3926405648152754
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0282.png
# ...
# (256, 256, 2) (256, 256, 1)
# 0.5709328997138993
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0705.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4352307182362933
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0704.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3062389359277245
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0706.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.46432671117050167
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0702.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.42458183902769414
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0695.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4366628944405139
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0698.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.44065473586163156
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0699.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.502606962461403
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0694.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.42822902251619704
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0696.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.421310388189682
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0692.png
# 1/1 [==============================] - 0s 25ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5706430369680873
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0693.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.49574594658882903
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0697.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5334560240639888
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0700.png
# 1/1 [==============================] - 0s 24ms/step
# (256, 256, 2) (256, 256, 1)
# 0.45699475837172693
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0691.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5136081652659512
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0743.png
# 1/1 [==============================] - 0s 24ms/step
# (256, 256, 2) (256, 256, 1)
# 0.499874370760175
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0746.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.29050525042720127
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0749.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3372655383878651
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0747.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3369517738321832
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0748.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.46331767809642727
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0741.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.49389244483013117
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0742.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4990358023773996
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0750.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.540070415653096
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0744.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.35608515560620996
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0745.png
# 1/1 [==============================] - 0s 25ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4413813513016198
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0737.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5034832239654888
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0736.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.508959456930714
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0735.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4688260187817918
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0739.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.38628747617866394
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0738.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5384613253102737
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0740.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.44475015037734017
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0734.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3960628202871737
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0731.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.37389276430888835
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0733.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.38538477926451614
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0732.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4694223272618987
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0727.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3677879551734829
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0725.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4387085068800145
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0730.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.36233734401578793
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0728.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.47078156947276106
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0722.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.40117007319108167
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0723.png
# 1/1 [==============================] - 0s 26ms/step
# (256, 256, 2) (256, 256, 1)
# 0.36817669406370035
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0729.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4367320305386004
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0724.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4155263973648569
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0726.png
# 1/1 [==============================] - 0s 24ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5064834634902079
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0721.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.42906721316959157
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0779.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4936563388643864
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0780.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4533958158202611
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0777.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3768500062186426
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0776.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.44361798531996843
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0778.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4339516703295807
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0774.png
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 2) (256, 256, 1)
# 0.35298685936293067
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0775.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.460408486150615
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0773.png
# 1/1 [==============================] - 0s 24ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4437756080052408
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0772.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.38023798760724775
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0771.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.33306375048642306
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0761.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4724513335475362
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0763.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.47257736491109564
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0766.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.379220593929761
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0767.png
# 1/1 [==============================] - 0s 24ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4723326065417058
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0764.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3527575764330863
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0768.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.30423580877754314
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0765.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4186120485394189
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0770.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4193643041622492
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0762.png
# 1/1 [==============================] - 0s 24ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5099460820351777
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0757.png
# 1/1 [==============================] - 0s 17ms/step
# (256, 256, 2) (256, 256, 1)
# 0.33644925997194597
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0760.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4016186149517657
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0758.png
# 1/1 [==============================] - 0s 24ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4684869342506501
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0754.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4092618911292976
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0755.png
# 1/1 [==============================] - 0s 24ms/step
# (256, 256, 2) (256, 256, 1)
# 0.39858193163277295
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0769.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.44349407549630193
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0751.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5136857495613693
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0753.png
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 2) (256, 256, 1)
# 0.47977404582508615
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0759.png
# 1/1 [==============================] - 0s 23ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4104252434562639
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0756.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4826826455945188
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0752.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4911694033053129
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0793.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.518763136611998
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0798.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4963109095632972
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0797.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4965878541525511
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0794.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4787757366382888
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0792.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5041313045821716
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0800.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.41997685411548596
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0791.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5303369059062738
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0796.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.41991757371914495
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0795.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3679368604068256
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0799.png
# 1/1 [==============================] - 0s 22ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5645182056753144
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0788.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.3697360643396476
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0790.png
# 1/1 [==============================] - 0s 21ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4125505812101657
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0789.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.4760863507005128
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0783.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5228360596181946
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0782.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5067777864982376
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0786.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.46825773272601334
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0781.png
# 1/1 [==============================] - 0s 18ms/step
# (256, 256, 2) (256, 256, 1)
# 0.580734401464929
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0785.png
# 1/1 [==============================] - 0s 24ms/step
# (256, 256, 2) (256, 256, 1)
# 0.569296992428042
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0784.png
# 1/1 [==============================] - 0s 20ms/step
# (256, 256, 2) (256, 256, 1)
# 0.5167375261569394
# /content/gdrive/MyDrive/Thesis/Dataset/div2k/DIV2K_train_256/0787.png
# 1/1 [==============================] - 0s 19ms/step
# (256, 256, 2) (256, 256, 1)
# 0.46382800847250927

# %%
import numpy as np
ps = np.array(psnr_list)
avg = ps.mean()
print('g100_1000x800_custom')
print("Avg",avg)
print("Max : ", ps.max())
print("Min : ",ps.min())
# Out:
# g100_1000x800_custom
# Avg 47.83041004678831
# Max :  49.79453278098241
# Min :  45.57727081798126

# %%
def result_show(test_data,filename):
    src_image, tar_image = test_data
    # generate image from source
    gen_image = model.predict(src_image)
    print(src_image.shape)
    # src_image = src_image[:,:,:]
    # src_image = np.squeeze(src_image)
    src_image = src_image.reshape((256,256,1))
    print(src_image.shape)
    gen_image = np.squeeze(gen_image)

    gen_Lab = np.concatenate([src_image, gen_image],axis = 2)
    gen_rgb = lab2rgb(gen_Lab)
    gen_rgb = np.array(gen_rgb).astype('uint8')

    tar_image = tar_image[0,:,:,:]
    print(gen_image.shape,src_image.shape,tar_image.shape)
    tar_Lab = np.concatenate([src_image, tar_image],axis = 2)
    tar_rgb = lab2rgb(tar_Lab)
    tar_rgb = np.array(tar_rgb).astype('uint8')

    save_path = 'D:\Thesis\output\hsv_PASCAL_VOC_g100\\'+filename
    

    # plot all three images
    # plot_images(src_image, gen_rgb, tar_rgb,save_path)
    plot_whole_images(src_image, gen_rgb, tar_rgb,save_path)

# %%
# plot source, generated and target images
def plot_whole_images(src_img, gen_img, tar_img,path):
  
  # images = vstack(( gen_img, tar_img))
  #images = src_img
  # scale from [-1,1] to [0,1]
  # images = (images + 1) / 2.0
  p, ax = pyplot.subplots(1,3)
  titles = ['Source', 'Generated', 'Expected']
  # ax[0].subplot(1,3)
  ax[0].axis('off')
  src_image = np.squeeze(src_img)
  ax[0].imshow(src_image,'gray')
  # ax[0].title(titles[0])

  # ax[1].subplot(1,3,2)
  ax[1].axis('off')
  # re = np.squeeze(gen_image)
  ax[1].imshow(gen_img,'gray')
  # ax[1].title(titles[1])

  # ax[2].subplot(1,3,3)
  ax[2].axis('off')
  # re = np.squeeze(tar_image)
  ax[2].imshow(tar_img,'gray')
  # ax[2].title(titles[2])

  '''# plot images row by row
  for i in range(len(images)):
    
    # define subplot
    pyplot.subplot(1, 3, 2 + i)# turn off axis
    pyplot.axis('off')# plot raw pixel data
    pyplot.imshow(images[i])# show title
    pyplot.title(titles[i+1])
  print(images.shape)'''
  # pyplot.subplot(1,3,1)
  # pyplot.imshow(images[0,:,:,:])
  # cv2.imwrite(filename,)
  # img = pyplot.show()
  # plt.imsave(path,img)
  # p.savefig(path)

# %%
result_show(test_data,"sdfhkjsdf")
# Out:
# (1, 256, 256)
# (256, 256, 1)
# (256, 256, 2) (256, 256, 1) (256, 256, 2)

# %%
def postprocess_data(data):
	# load compressed arrays
	# unpack arrays
	# X1, X2 = data[0], data[1]
	# scale from [0,255] to [-1,1]
	X1 = (data * 127.5) + 127.5
	# X2 = (X2 - 127.5) / 127.5
	return X1

# %%
gen_Lab = np.concatenate([src_image.reshape(256,256,1), tar_image[0,:,:,:]],axis = 2)
gen_Lab = lab2rgb(gen_Lab)
gen_Lab = postprocess_data(gen_Lab)
plt.imshow(gen_Lab,'gray')
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
gen_Lab.shape
# Out:
# (256, 256, 3)

# %%
gen_Lab.min()
# Out:
# 127.5
